# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 589

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = weather_api_key

# Starting URL for Weather Map API Call
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

setting = {'units':'Imperial','appid':api_key}
desired_keys = ['clouds.all','sys.country','dt','main.humidity','main.temp_max','wind.speed','coord.lat','coord.lon']

cloudiness = []
country = []
date = []
humidity = []
max_temp = []
wind_speed = []
lat =[]
lng =[]
cities_list = []

print('Beginning Data Retrieval')
print('---------------------')
counter = 1
for city in cities:
    city_url = base_url + '&q=' + city.replace(' ','+')
    print(f'Processing City # {counter} | {city}')
    print(city_url)
    try:
        city_data = ow.get_current(city,**setting)
        cl,ct,dt,hm,mt,ws,lt,ln = city_data(*desired_keys)
        cloudiness.append(cl)
        country.append(ct)
        date.append(dt)
        humidity.append(hm)
        max_temp.append(mt)
        wind_speed.append(ws)
        lat.append(lt)
        lng.append(ln)
        cities_list.append(city)
    except NameError:
        print('City not found. skipping...')
    counter += 1
print('---------------------')
print('Data Retrieval Complete')
# Out:
# Beginning Data Retrieval
# ---------------------
# Processing City # 1 | pangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=pangani
# City not found. skipping...
# Processing City # 2 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=nabire
# City not found. skipping...
# Processing City # 3 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=katsuura
# City not found. skipping...
# Processing City # 4 | kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kiama
# City not found. skipping...
# Processing City # 5 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=barrow
# City not found. skipping...
# Processing City # 6 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=faanui
# City not found. skipping...
# Processing City # 7 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=hithadhoo
# City not found. skipping...
# Processing City # 8 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=airai
# City not found. skipping...
# Processing City # 9 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mahebourg
# City not found. skipping...
# Processing City # 10 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=peniche
# City not found. skipping...
# Processing City # 11 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tsihombe
# City not found. skipping...
# Processing City # 12 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=seoul
# City not found. skipping...
# Processing City # 13 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=punta+arenas
# City not found. skipping...
# Processing City # 14 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=hilo
# City not found. skipping...
# Processing City # 15 | grand forks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=grand+forks
# City not found. skipping...
# Processing City # 16 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=lata
# City not found. skipping...
# Processing City # 17 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sibolga
# City not found. skipping...
# Processing City # 18 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bambous+virieux
# City not found. skipping...
# Processing City # 19 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=port+alfred
# City not found. skipping...
# Processing City # 20 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=georgetown
# City not found. skipping...
# Processing City # 21 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=rikitea
# City not found. skipping...
# Processing City # 22 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=paamiut
# City not found. skipping...
# Processing City # 23 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kruisfontein
# City not found. skipping...
# Processing City # 24 | grand centre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=grand+centre
# City not found. skipping...
# Processing City # 25 | evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=evensk
# City not found. skipping...
# Processing City # 26 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kahului
# City not found. skipping...
# Processing City # 27 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tautira
# City not found. skipping...
# Processing City # 28 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bengkulu
# City not found. skipping...
# Processing City # 29 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tiksi
# City not found. skipping...
# Processing City # 30 | ust-koksa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ust-koksa
# City not found. skipping...
# Processing City # 31 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kloulklubed
# City not found. skipping...
# Processing City # 32 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bethel
# City not found. skipping...
# Processing City # 33 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=geraldton
# City not found. skipping...
# Processing City # 34 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=avarua
# City not found. skipping...
# Processing City # 35 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=hermanus
# City not found. skipping...
# Processing City # 36 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=muros
# City not found. skipping...
# Processing City # 37 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mataura
# City not found. skipping...
# Processing City # 38 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kapaa
# City not found. skipping...
# Processing City # 39 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=albany
# City not found. skipping...
# Processing City # 40 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=busselton
# City not found. skipping...
# Processing City # 41 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=puerto+ayora
# City not found. skipping...
# Processing City # 42 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=vaini
# City not found. skipping...
# Processing City # 43 | warqla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=warqla
# City not found. skipping...
# Processing City # 44 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=cape+town
# City not found. skipping...
# Processing City # 45 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=constitucion
# City not found. skipping...
# Processing City # 46 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=caravelas
# City not found. skipping...
# Processing City # 47 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=hobyo
# City not found. skipping...
# Processing City # 48 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sentyabrskiy
# City not found. skipping...
# Processing City # 49 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=beringovskiy
# City not found. skipping...
# Processing City # 50 | pokhara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=pokhara
# City not found. skipping...
# Processing City # 51 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tasiilaq
# City not found. skipping...
# Processing City # 52 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=saldanha
# City not found. skipping...
# Processing City # 53 | chengam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=chengam
# City not found. skipping...
# Processing City # 54 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=banda+aceh
# City not found. skipping...
# Processing City # 55 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=guerrero+negro
# City not found. skipping...
# Processing City # 56 | shahjahanpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=shahjahanpur
# City not found. skipping...
# Processing City # 57 | rudnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=rudnogorsk
# City not found. skipping...
# Processing City # 58 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=quatre+cocos
# City not found. skipping...
# Processing City # 59 | fort-shevchenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=fort-shevchenko
# City not found. skipping...
# Processing City # 60 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ushuaia
# City not found. skipping...
# Processing City # 61 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=saleaula
# City not found. skipping...
# Processing City # 62 | carmen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=carmen
# City not found. skipping...
# Processing City # 63 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=khatanga
# City not found. skipping...
# Processing City # 64 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=dikson
# City not found. skipping...
# Processing City # 65 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=antofagasta
# City not found. skipping...
# Processing City # 66 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=atuona
# City not found. skipping...
# Processing City # 67 | anchorage
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=anchorage
# City not found. skipping...
# Processing City # 68 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=grand+gaube
# City not found. skipping...
# Processing City # 69 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=nizhneyansk
# City not found. skipping...
# Processing City # 70 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=cidreira
# City not found. skipping...
# Processing City # 71 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=barentsburg
# City not found. skipping...
# Processing City # 72 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=carnarvon
# City not found. skipping...
# Processing City # 73 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bluff
# City not found. skipping...
# Processing City # 74 | mrirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mrirt
# City not found. skipping...
# Processing City # 75 | latung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=latung
# City not found. skipping...
# Processing City # 76 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=chokurdakh
# City not found. skipping...
# Processing City # 77 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=talnakh
# City not found. skipping...
# Processing City # 78 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mys+shmidta
# City not found. skipping...
# Processing City # 79 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=lorengau
# City not found. skipping...
# Processing City # 80 | taveta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=taveta
# City not found. skipping...
# Processing City # 81 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=esperance
# City not found. skipping...
# Processing City # 82 | dhamrai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=dhamrai
# City not found. skipping...
# Processing City # 83 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=nikolskoye
# City not found. skipping...
# Processing City # 84 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=iqaluit
# City not found. skipping...
# Processing City # 85 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=umm+kaddadah
# City not found. skipping...
# Processing City # 86 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tuktoyaktuk
# City not found. skipping...
# Processing City # 87 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=shimoda
# City not found. skipping...
# Processing City # 88 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=qaanaaq
# City not found. skipping...
# Processing City # 89 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=san+cristobal
# City not found. skipping...
# Processing City # 90 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=yellowknife
# City not found. skipping...
# Processing City # 91 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=dingle
# City not found. skipping...
# Processing City # 92 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=itarema
# City not found. skipping...
# Processing City # 93 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=taolanaro
# City not found. skipping...
# Processing City # 94 | nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=nizwa
# City not found. skipping...
# Processing City # 95 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=saint-philippe
# City not found. skipping...
# Processing City # 96 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=castro
# City not found. skipping...
# Processing City # 97 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sao+filipe
# City not found. skipping...
# Processing City # 98 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sao+joao+da+barra
# City not found. skipping...
# Processing City # 99 | taga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=taga
# City not found. skipping...
# Processing City # 100 | nara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=nara
# City not found. skipping...
# Processing City # 101 | waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=waingapu
# City not found. skipping...
# Processing City # 102 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=grand+river+south+east
# City not found. skipping...
# Processing City # 103 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=thompson
# City not found. skipping...
# Processing City # 104 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=jamestown
# City not found. skipping...
# Processing City # 105 | blagoyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=blagoyevo
# City not found. skipping...
# Processing City # 106 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=hasaki
# City not found. skipping...
# Processing City # 107 | kailua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kailua
# City not found. skipping...
# Processing City # 108 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=port+elizabeth
# City not found. skipping...
# Processing City # 109 | phan rang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=phan+rang
# City not found. skipping...
# Processing City # 110 | iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=iracoubo
# City not found. skipping...
# Processing City # 111 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=luderitz
# City not found. skipping...
# Processing City # 112 | anandpur sahib
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=anandpur+sahib
# City not found. skipping...
# Processing City # 113 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=new+norfolk
# City not found. skipping...
# Processing City # 114 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ucluelet
# City not found. skipping...
# Processing City # 115 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=samarai
# City not found. skipping...
# Processing City # 116 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ixtapa
# City not found. skipping...
# Processing City # 117 | naliya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=naliya
# City not found. skipping...
# Processing City # 118 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=gat
# City not found. skipping...
# Processing City # 119 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tessalit
# City not found. skipping...
# Processing City # 120 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=san+quintin
# City not found. skipping...
# Processing City # 121 | cacapava do sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=cacapava+do+sul
# City not found. skipping...
# Processing City # 122 | mortka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mortka
# City not found. skipping...
# Processing City # 123 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=amderma
# City not found. skipping...
# Processing City # 124 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=arraial+do+cabo
# City not found. skipping...
# Processing City # 125 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=turukhansk
# City not found. skipping...
# Processing City # 126 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=chapais
# City not found. skipping...
# Processing City # 127 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=hervey+bay
# City not found. skipping...
# Processing City # 128 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=nome
# City not found. skipping...
# Processing City # 129 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=saint+george
# City not found. skipping...
# Processing City # 130 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=nanortalik
# City not found. skipping...
# Processing City # 131 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=inirida
# City not found. skipping...
# Processing City # 132 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=cherskiy
# City not found. skipping...
# Processing City # 133 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=saskylakh
# City not found. skipping...
# Processing City # 134 | katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=katobu
# City not found. skipping...
# Processing City # 135 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=torbay
# City not found. skipping...
# Processing City # 136 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kirakira
# City not found. skipping...
# Processing City # 137 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=verkhoyansk
# City not found. skipping...
# Processing City # 138 | tongsa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tongsa
# City not found. skipping...
# Processing City # 139 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=poum
# City not found. skipping...
# Processing City # 140 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ribeira+grande
# City not found. skipping...
# Processing City # 141 | inderborskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=inderborskiy
# City not found. skipping...
# Processing City # 142 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=victoria
# City not found. skipping...
# Processing City # 143 | bagotville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bagotville
# City not found. skipping...
# Processing City # 144 | buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=buchanan
# City not found. skipping...
# Processing City # 145 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=leh
# City not found. skipping...
# Processing City # 146 | bejar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bejar
# City not found. skipping...
# Processing City # 147 | vilhena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=vilhena
# City not found. skipping...
# Processing City # 148 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=saint+anthony
# City not found. skipping...
# Processing City # 149 | skeldon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=skeldon
# City not found. skipping...
# Processing City # 150 | alappuzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=alappuzha
# City not found. skipping...
# Processing City # 151 | borova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=borova
# City not found. skipping...
# Processing City # 152 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=upernavik
# City not found. skipping...
# Processing City # 153 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=olinda
# City not found. skipping...
# Processing City # 154 | lima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=lima
# City not found. skipping...
# Processing City # 155 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=vostok
# City not found. skipping...
# Processing City # 156 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kodiak
# City not found. skipping...
# Processing City # 157 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=provideniya
# City not found. skipping...
# Processing City # 158 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=souillac
# City not found. skipping...
# Processing City # 159 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tuatapere
# City not found. skipping...
# Processing City # 160 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=petropavlovsk-kamchatskiy
# City not found. skipping...
# Processing City # 161 | jishou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=jishou
# City not found. skipping...
# Processing City # 162 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=hambantota
# City not found. skipping...
# Processing City # 163 | manzil tamim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=manzil+tamim
# City not found. skipping...
# Processing City # 164 | rayagada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=rayagada
# City not found. skipping...
# Processing City # 165 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=butaritari
# City not found. skipping...
# Processing City # 166 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=yar-sale
# City not found. skipping...
# Processing City # 167 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=port-cartier
# City not found. skipping...
# Processing City # 168 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=saint-francois
# City not found. skipping...
# Processing City # 169 | artyom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=artyom
# City not found. skipping...
# Processing City # 170 | ralivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ralivka
# City not found. skipping...
# Processing City # 171 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=clyde+river
# City not found. skipping...
# Processing City # 172 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=marcona
# City not found. skipping...
# Processing City # 173 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=hobart
# City not found. skipping...
# Processing City # 174 | kerema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kerema
# City not found. skipping...
# Processing City # 175 | karamea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=karamea
# City not found. skipping...
# Processing City # 176 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tual
# City not found. skipping...
# Processing City # 177 | ringebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ringebu
# City not found. skipping...
# Processing City # 178 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=portland
# City not found. skipping...
# Processing City # 179 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=chuy
# City not found. skipping...
# Processing City # 180 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=udachnyy
# City not found. skipping...
# Processing City # 181 | santa marta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=santa+marta
# City not found. skipping...
# Processing City # 182 | kargasok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kargasok
# City not found. skipping...
# Processing City # 183 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kavaratti
# City not found. skipping...
# Processing City # 184 | post falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=post+falls
# City not found. skipping...
# Processing City # 185 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=college
# City not found. skipping...
# Processing City # 186 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=broome
# City not found. skipping...
# Processing City # 187 | sampit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sampit
# City not found. skipping...
# Processing City # 188 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=fort+nelson
# City not found. skipping...
# Processing City # 189 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=port+lincoln
# City not found. skipping...
# Processing City # 190 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=puerto+escondido
# City not found. skipping...
# Processing City # 191 | nakamura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=nakamura
# City not found. skipping...
# Processing City # 192 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=husavik
# City not found. skipping...
# Processing City # 193 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=half+moon+bay
# City not found. skipping...
# Processing City # 194 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=palmer
# City not found. skipping...
# Processing City # 195 | solenzo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=solenzo
# City not found. skipping...
# Processing City # 196 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ornskoldsvik
# City not found. skipping...
# Processing City # 197 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=port+macquarie
# City not found. skipping...
# Processing City # 198 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=leningradskiy
# City not found. skipping...
# Processing City # 199 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=korla
# City not found. skipping...
# Processing City # 200 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kaitangata
# City not found. skipping...
# Processing City # 201 | navahrudak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=navahrudak
# City not found. skipping...
# Processing City # 202 | chachapoyas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=chachapoyas
# City not found. skipping...
# Processing City # 203 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=cayenne
# City not found. skipping...
# Processing City # 204 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=lompoc
# City not found. skipping...
# Processing City # 205 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=deputatskiy
# City not found. skipping...
# Processing City # 206 | merrill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=merrill
# City not found. skipping...
# Processing City # 207 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sorland
# City not found. skipping...
# Processing City # 208 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=san+patricio
# City not found. skipping...
# Processing City # 209 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=east+london
# City not found. skipping...
# Processing City # 210 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tiarei
# City not found. skipping...
# Processing City # 211 | oussouye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=oussouye
# City not found. skipping...
# Processing City # 212 | nsoko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=nsoko
# City not found. skipping...
# Processing City # 213 | noyabrsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=noyabrsk
# City not found. skipping...
# Processing City # 214 | da nang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=da+nang
# City not found. skipping...
# Processing City # 215 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=haines+junction
# City not found. skipping...
# Processing City # 216 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mar+del+plata
# City not found. skipping...
# Processing City # 217 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=brae
# City not found. skipping...
# Processing City # 218 | awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=awbari
# City not found. skipping...
# Processing City # 219 | pasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=pasan
# City not found. skipping...
# Processing City # 220 | milkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=milkovo
# City not found. skipping...
# Processing City # 221 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=touros
# City not found. skipping...
# Processing City # 222 | palauig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=palauig
# City not found. skipping...
# Processing City # 223 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=anadyr
# City not found. skipping...
# Processing City # 224 | puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=puerto+del+rosario
# City not found. skipping...
# Processing City # 225 | puerto narino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=puerto+narino
# City not found. skipping...
# Processing City # 226 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kununurra
# City not found. skipping...
# Processing City # 227 | amga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=amga
# City not found. skipping...
# Processing City # 228 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=lagoa
# City not found. skipping...
# Processing City # 229 | dubbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=dubbo
# City not found. skipping...
# Processing City # 230 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=norman+wells
# City not found. skipping...
# Processing City # 231 | kokopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kokopo
# City not found. skipping...
# Processing City # 232 | snasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=snasa
# City not found. skipping...
# Processing City # 233 | puerto baquerizo moreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=puerto+baquerizo+moreno
# City not found. skipping...
# Processing City # 234 | hawalli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=hawalli
# City not found. skipping...
# Processing City # 235 | bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bilma
# City not found. skipping...
# Processing City # 236 | biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=biltine
# City not found. skipping...
# Processing City # 237 | ibra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ibra
# City not found. skipping...
# Processing City # 238 | aksum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=aksum
# City not found. skipping...
# Processing City # 239 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=lebu
# City not found. skipping...
# Processing City # 240 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=belushya+guba
# City not found. skipping...
# Processing City # 241 | puerto cabezas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=puerto+cabezas
# City not found. skipping...
# Processing City # 242 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=vestmannaeyjar
# City not found. skipping...
# Processing City # 243 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=namibe
# City not found. skipping...
# Processing City # 244 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sisimiut
# City not found. skipping...
# Processing City # 245 | crailsheim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=crailsheim
# City not found. skipping...
# Processing City # 246 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=avera
# City not found. skipping...
# Processing City # 247 | sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sorong
# City not found. skipping...
# Processing City # 248 | sanica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sanica
# City not found. skipping...
# Processing City # 249 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=rocha
# City not found. skipping...
# Processing City # 250 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=oranjemund
# City not found. skipping...
# Processing City # 251 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=vardo
# City not found. skipping...
# Processing City # 252 | kuruman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kuruman
# City not found. skipping...
# Processing City # 253 | xixiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=xixiang
# City not found. skipping...
# Processing City # 254 | innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=innisfail
# City not found. skipping...
# Processing City # 255 | mundargi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mundargi
# City not found. skipping...
# Processing City # 256 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=meulaboh
# City not found. skipping...
# Processing City # 257 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=salinopolis
# City not found. skipping...
# Processing City # 258 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sitka
# City not found. skipping...
# Processing City # 259 | miandoab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=miandoab
# City not found. skipping...
# Processing City # 260 | mookane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mookane
# City not found. skipping...
# Processing City # 261 | shirgaon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=shirgaon
# City not found. skipping...
# Processing City # 262 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=los+llanos+de+aridane
# City not found. skipping...
# Processing City # 263 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=grindavik
# City not found. skipping...
# Processing City # 264 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bredasdorp
# City not found. skipping...
# Processing City # 265 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=wanning
# City not found. skipping...
# Processing City # 266 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=pacific+grove
# City not found. skipping...
# Processing City # 267 | candolim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=candolim
# City not found. skipping...
# Processing City # 268 | tuensang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tuensang
# City not found. skipping...
# Processing City # 269 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ponta+do+sol
# City not found. skipping...
# Processing City # 270 | newport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=newport
# City not found. skipping...
# Processing City # 271 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=codrington
# City not found. skipping...
# Processing City # 272 | mandalgarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mandalgarh
# City not found. skipping...
# Processing City # 273 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=illoqqortoormiut
# City not found. skipping...
# Processing City # 274 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=aklavik
# City not found. skipping...
# Processing City # 275 | timizart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=timizart
# City not found. skipping...
# Processing City # 276 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=honiara
# ...
# City not found. skipping...
# Processing City # 499 | ust-ilimsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ust-ilimsk
# City not found. skipping...
# Processing City # 500 | falealupo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=falealupo
# City not found. skipping...
# Processing City # 501 | manicore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=manicore
# City not found. skipping...
# Processing City # 502 | karoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=karoi
# City not found. skipping...
# Processing City # 503 | pellerd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=pellerd
# City not found. skipping...
# Processing City # 504 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tezu
# City not found. skipping...
# Processing City # 505 | gardez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=gardez
# City not found. skipping...
# Processing City # 506 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tilichiki
# City not found. skipping...
# Processing City # 507 | bourail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bourail
# City not found. skipping...
# Processing City # 508 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sinnamary
# City not found. skipping...
# Processing City # 509 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mayo
# City not found. skipping...
# Processing City # 510 | bangui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bangui
# City not found. skipping...
# Processing City # 511 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=richards+bay
# City not found. skipping...
# Processing City # 512 | lahij
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=lahij
# City not found. skipping...
# Processing City # 513 | mumford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mumford
# City not found. skipping...
# Processing City # 514 | tuy hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tuy+hoa
# City not found. skipping...
# Processing City # 515 | gorno-chuyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=gorno-chuyskiy
# City not found. skipping...
# Processing City # 516 | khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=khasan
# City not found. skipping...
# Processing City # 517 | benjamin constant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=benjamin+constant
# City not found. skipping...
# Processing City # 518 | ngukurr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ngukurr
# City not found. skipping...
# Processing City # 519 | chippewa falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=chippewa+falls
# City not found. skipping...
# Processing City # 520 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=raudeberg
# City not found. skipping...
# Processing City # 521 | pringsewu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=pringsewu
# City not found. skipping...
# Processing City # 522 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=rawson
# City not found. skipping...
# Processing City # 523 | litoral del san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=litoral+del+san+juan
# City not found. skipping...
# Processing City # 524 | gisborne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=gisborne
# City not found. skipping...
# Processing City # 525 | tiruchchendur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tiruchchendur
# City not found. skipping...
# Processing City # 526 | katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=katherine
# City not found. skipping...
# Processing City # 527 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=zhigansk
# City not found. skipping...
# Processing City # 528 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ostrovnoy
# City not found. skipping...
# Processing City # 529 | akdepe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=akdepe
# City not found. skipping...
# Processing City # 530 | bajo baudo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bajo+baudo
# City not found. skipping...
# Processing City # 531 | guarapuava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=guarapuava
# City not found. skipping...
# Processing City # 532 | neuquen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=neuquen
# City not found. skipping...
# Processing City # 533 | sompeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sompeta
# City not found. skipping...
# Processing City # 534 | walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=walvis+bay
# City not found. skipping...
# Processing City # 535 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=havelock
# City not found. skipping...
# Processing City # 536 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=lasa
# City not found. skipping...
# Processing City # 537 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=margate
# City not found. skipping...
# Processing City # 538 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=hamilton
# City not found. skipping...
# Processing City # 539 | pithapuram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=pithapuram
# City not found. skipping...
# Processing City # 540 | jesup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=jesup
# City not found. skipping...
# Processing City # 541 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=saint-georges
# City not found. skipping...
# Processing City # 542 | chalons-en-champagne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=chalons-en-champagne
# City not found. skipping...
# Processing City # 543 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=antalaha
# City not found. skipping...
# Processing City # 544 | kipini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kipini
# City not found. skipping...
# Processing City # 545 | lapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=lapa
# City not found. skipping...
# Processing City # 546 | barsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=barsi
# City not found. skipping...
# Processing City # 547 | mentok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mentok
# City not found. skipping...
# Processing City # 548 | todos santos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=todos+santos
# City not found. skipping...
# Processing City # 549 | tampocon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tampocon
# City not found. skipping...
# Processing City # 550 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kangaatsiaq
# City not found. skipping...
# Processing City # 551 | san jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=san+jose
# City not found. skipping...
# Processing City # 552 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=umzimvubu
# City not found. skipping...
# Processing City # 553 | funadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=funadhoo
# City not found. skipping...
# Processing City # 554 | edgewater
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=edgewater
# City not found. skipping...
# Processing City # 555 | sayabec
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=sayabec
# City not found. skipping...
# Processing City # 556 | bluefield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bluefield
# City not found. skipping...
# Processing City # 557 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=cap+malheureux
# City not found. skipping...
# Processing City # 558 | wanaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=wanaka
# City not found. skipping...
# Processing City # 559 | atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=atasu
# City not found. skipping...
# Processing City # 560 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=goderich
# City not found. skipping...
# Processing City # 561 | xinqing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=xinqing
# City not found. skipping...
# Processing City # 562 | ekhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ekhabi
# City not found. skipping...
# Processing City # 563 | monywa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=monywa
# City not found. skipping...
# Processing City # 564 | omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=omsukchan
# City not found. skipping...
# Processing City # 565 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=belmonte
# City not found. skipping...
# Processing City # 566 | magdalena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=magdalena
# City not found. skipping...
# Processing City # 567 | yunjinghong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=yunjinghong
# City not found. skipping...
# Processing City # 568 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=umm+lajj
# City not found. skipping...
# Processing City # 569 | shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=shache
# City not found. skipping...
# Processing City # 570 | ambulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ambulu
# City not found. skipping...
# Processing City # 571 | abu zabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=abu+zabad
# City not found. skipping...
# Processing City # 572 | omagari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=omagari
# City not found. skipping...
# Processing City # 573 | carauari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=carauari
# City not found. skipping...
# Processing City # 574 | diego de almagro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=diego+de+almagro
# City not found. skipping...
# Processing City # 575 | bela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=bela
# City not found. skipping...
# Processing City # 576 | san miguel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=san+miguel
# City not found. skipping...
# Processing City # 577 | manaure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=manaure
# City not found. skipping...
# Processing City # 578 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=nouadhibou
# City not found. skipping...
# Processing City # 579 | mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=mnogovershinnyy
# City not found. skipping...
# Processing City # 580 | tukums
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=tukums
# City not found. skipping...
# Processing City # 581 | ocampo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=ocampo
# City not found. skipping...
# Processing City # 582 | kuala pilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=kuala+pilah
# City not found. skipping...
# Processing City # 583 | pauini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=pauini
# City not found. skipping...
# Processing City # 584 | wuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=wuan
# City not found. skipping...
# Processing City # 585 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=nelson+bay
# City not found. skipping...
# Processing City # 586 | pasighat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=pasighat
# City not found. skipping...
# Processing City # 587 | casper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=casper
# City not found. skipping...
# Processing City # 588 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=shingu
# City not found. skipping...
# Processing City # 589 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5896c5d3ed4b2d3d6be11e4342a1a4a7&q=derzhavinsk
# City not found. skipping...
# ---------------------
# Data Retrieval Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({
    "City":cities_list,
    "Cloudiness":cloudiness,
    "Country":country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temp,
    "Wind Speed":wind_speed,
     })
weather_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-d6259c9c04a9> in <module>
#       8     "Lng":lngs,
#       9     "Max Temp":max_temp,
# ---> 10     "Wind Speed":wind_speed,
#      11      })
#      12 weather_df.head()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
